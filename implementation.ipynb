# %%
from absenteeism_module import *

model = absenteeism_model('logreg_model', 'scaler')
model.load_and_clean_data('new_data.csv')
df = model.predicted_outputs()

df.to_csv('new_data_predictions')
df.head()
# Out:
# /Users/rwilley/Desktop/Data Science Learning/Projects.nosync/integrate_python_tableau_sql/absenteeism_module.py:44: DataConversionWarning: Data with input dtype int64, float64 were all converted to float64 by StandardScaler.
#   X_scaled = pd.DataFrame(self.scaler.transform(X[self.columns]), columns=self.columns)
#    Transportation_Expense  Distance_to_Work  Age  Daily_Work_Load_Average  \
# 0                     179                26   30                  237.656
# 1                     361                52   28                  237.656
# 2                     155                12   34                  237.656
# 3                     179                22   40                  237.656
# 4                     155                12   34                  237.656
#
#    Body_Mass_Index  Education  Children  Pets  Sickness  Pregnancy  Injury  \
# 0               19          1         0     0         0          0       0
# ...
